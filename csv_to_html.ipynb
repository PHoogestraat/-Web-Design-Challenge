# %% [markdown]
# # Web Visualization Dashboard (Latitude)
#
# Convert csv file to:
#
#     1) Data frame
#
#     2) html
#
#     3) Export HTML file

# %%
import pandas as pd

# %%
weather_data = pd.read_csv("data/big_weather_data_df.csv")
weather_data.head()
# Out:
#    Unnamed: 0  City ID                City Country Code  Latitude  Longitude  \
# 0           0   662096           Äänekoski           FI     62.69      25.82
# 1           1  1512223              Abalak           RU     58.13      68.59
# 2           2   110690                Abhā           SA     18.22      42.51
# 3           3   172515          Abu Samrah           SY     35.30      37.18
# 4           4  3533462  Acapulco de Juárez           MX     16.86     -99.89
#
#    Temp Kelvin  Temp C  Temp F  Humidity (RH)%  Cloud% Cover  \
# 0       276.62     3.0    38.0              93            90
# 1       262.36   -11.0    13.0              95            63
# 2       282.55     9.0    49.0              28             0
# 3       284.78    12.0    53.0              82            11
# 4       300.15    27.0    81.0              88             5
#
#    wind speed (m/s)  wind speed (mph)                Time stamp
# 0              3.60              8.00  ['22 Nov 2020 21:55:58']
# ...

# %%
html_table = weather_data.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City ID</th>\n      <th>City</th>\n      <th>Country Code</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temp Kelvin</th>\n      <th>Temp C</th>\n      <th>Temp F</th>\n      <th>Humidity (RH)%</th>\n      <th>Cloud% Cover</th>\n      <th>wind speed (m/s)</th>\n      <th>wind speed (mph)</th>\n      <th>Time stamp</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>662096</td>\n      <td>Äänekoski</td>\n      <td>FI</td>\n      <td>62.69</td>\n      <td>25.82</td>\n      <td>276.62</td>\n      <td>3.0</td>\n      <td>38.0</td>\n      <td>93</td>\n      <td>90</td>\n      <td>3.60</td>\n      <td>8.00</td>\n      <td>[\'22 Nov 2020 21:55:58\']</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>1512223</td>\n      <td>Abalak</td>\n      <td>RU</td>\n      <td>58.
# ...

# %%
weather_data.to_html('data/weather_data.html')
