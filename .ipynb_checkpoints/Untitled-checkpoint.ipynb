# %% [markdown]
# # Web Visualization Dashboard (Latitude)
#
# Convert csv file to html

# %%
import pandas as pd

# %%
weather_data = pd.read_csv("data/big_weather_data_df.csv")
weather_data.head()
# Out:
#    Unnamed: 0  City ID       City Country Code  Latitude  Longitude  \
# 0           0  3119841   A Coruña           ES     43.37      -8.40
# 1           1   110690       Abhā           SA     18.22      42.51
# 2           2   362973      Abnūb           EG     27.27      31.15
# 3           3   174448  Abu Kamal           SY     34.45      40.92
# 4           4   380348  Abū Zabad           SD     12.35      29.25
#
#    Temp Kelvin  Temp C  Temp F  Humidity (RH)%  Cloud% Cover  \
# 0       288.13    15.0    59.0              77             0
# 1       295.15    22.0    72.0              12             0
# 2       293.15    20.0    68.0              45             0
# 3       289.60    17.0    62.0              44             0
# 4       299.50    26.0    79.0              17             2
#
#    wind speed (m/s)  wind speed (mph)                Time stamp
# 0              2.10              4.67  ['22 Nov 2020 11:19:59']
# ...

# %%
data.to_html('table.html').to_html('table.html')
